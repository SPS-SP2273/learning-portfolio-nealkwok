# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need) Exercises</span></div>

# %% [markdown]
# ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/exerise_icon.png)

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# **Exercise 1 (Fill in the blanks)** Fill in the blanks(indicated with a ?), so the code below will produce the plot shown.

# %% [markdown]
# ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/__imgs__/plotting_need_exercise-01_solution.png)

# %% [markdown]
# ```
# # Some data for plotting
# x = [0, 1, 2, 3, 4, 5]
# y = [0, 4, 8, 12, 16, 20]
# y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
# x_err = .25
#
# plt.errorbar(x, y,
#              xerr=?, yerr=?,
#              color=?, linestyle=?,
#              marker=?, markerfacecolor=?,
#              ecolor=?,capsize=5,
#              label=?)
# plt.xlabel('x-values')
# plt.ylabel('y-values')
# plt.title('X vs Y')
# plt.grid(alpha=.25)
# plt.legend(?)
# plt.show()
#
# ```

# %%
from matplotlib import pyplot as plt

# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, 
             xerr=x_err, yerr=y_err,
             color='darkred', linestyle='dashed',
             marker='o', markerfacecolor='yellow',
             ecolor='black',capsize=5,
             label='Y values with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Exercise 2 (A simple mathematical plot)

# %% [markdown]
# 1. Use NumPy to generate $x$ and $y$ data suitable for plotting the graph of the function:
#
#     $$
# y = {e^{-x/10}}{sin(x)}
#     $$
#
#     for values of $x$ in the range $0$ to $50$.
#
# 2. Customise your plot so that:
#     1. The x and y axes have labels of `fontsize` of 15.
#     2. The x and y axes labels are in the `color`, `darkorange`.
#     3. There is a grid with an opacity of 25%.
#     4. Indicate the equation of the function in the title with a font size of 20.
#     > Hint: Look at [Writing mathematical expressions](https://matplotlib.org/stable/users/explain/text/mathtext.html) in Matplotlib.
#     5. Change the $y$ limit (using `ylim`) to $[1,1]$.

# %% [markdown]
# ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/__imgs__/plotting_need_exercise-02_solution.png)

# %%
import numpy as np
import math 

x = np.linspace(0, 50, 1000)                               # put a high number for number of plot points to smooth the curve~~~
y = np.exp(-x / 10)*np.sin(x)                              # numpy math expressions

plt.plot(x, y, color='steelblue')                          # took me longer than I want to admit to identify this color
plt.ylim([-1, 1])

plt.xlabel('x', color='darkorange', fontsize = 15)
plt.ylabel('y', color='darkorange', fontsize = 15)
plt.title('y=e$^{-x/10}$sin(x)', fontsize = 20)

plt.grid(alpha=.25)
